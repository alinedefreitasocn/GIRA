# %%
from gira.load_data import load, load_sample
from gira import preprocess
from gira.plot_map import scatter
import pandas as pd

# %%
df = load_sample()

# %%
df_cleaned = preprocess.cleaning(df)
df_transformed = preprocess.processing_columns(df_cleaned)
# Out:
# Extracting the station name
#
# -------------------------
#
# Setting the station ID as an integer
#
# -------------------------
#
# Extracting geographical position
#
# -------------------------
#
# Dropping the columns position and designcomercial
#
# -------------------------
#
# Preprocess completed!

# %%
processed_stations = preprocess.process_all_station(df_transformed)
# Out:
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------
#
# Sorting values by datetime
#
# -------------------------
#
# Calculating the time step
#
# -------------------------
#
# Setting the time column as index
#
# -------------------------
#
# Resampling to 1 hour timestep
# Calculating the diff in the n. bike column
#
# -------------------------

# %%
processed_stations.head()
# Out:
#                            numbicicletas  numdocas  \
# entity_ts
# 2022-07-01 00:00:00+00:00           17.0      20.0
# 2022-07-01 01:00:00+00:00           19.0      20.0
# 2022-07-01 02:00:00+00:00           19.0      20.0
# 2022-07-01 03:00:00+00:00           19.0      20.0
# 2022-07-01 04:00:00+00:00           19.0      20.0
#
#                                                             station_name  \
# entity_ts
# 2022-07-01 00:00:00+00:00   Avenida Cidade de Lourenço Marques / Vale do
# 2022-07-01 01:00:00+00:00   Avenida Cidade de Lourenço Marques / Vale do
# 2022-07-01 02:00:00+00:00   Avenida Cidade de Lourenço Marques / Vale do
# 2022-07-01 03:00:00+00:00   Avenida Cidade de Lourenço Marques / Vale do
# 2022-07-01 04:00:00+00:00   Avenida Cidade de Lourenço Marques / Vale do
#
#                                  lat       lon  stationID  estado  \
# entity_ts
# 2022-07-01 00:00:00+00:00  38.764067 -9.118689      135.0  active
# 2022-07-01 01:00:00+00:00  38.764067 -9.118689      135.0  active
# 2022-07-01 02:00:00+00:00  38.764067 -9.118689      135.0  active
# 2022-07-01 03:00:00+00:00  38.764067 -9.118689      135.0  active
# 2022-07-01 04:00:00+00:00  38.764067 -9.118689      135.0  active
#
#                                           diff_time  total_seconds  bike_taken
# entity_ts
# 2022-07-01 00:00:00+00:00    0 days 00:10:00.107500          600.0         0.0
# 2022-07-01 01:00:00+00:00    0 days 00:30:00.872000         1800.5         2.0
# 2022-07-01 02:00:00+00:00 0 days 00:20:00.238333333         1200.0         0.0
# 2022-07-01 03:00:00+00:00    0 days 00:40:01.697000         2401.0         0.0
# 2022-07-01 04:00:00+00:00    0 days 00:40:01.896500         2401.5         0.0

# %%
processed_stations.shape
# Out:
# (100146, 10)

# %%
processed_stations.isna().sum()
# Out:
# numbicicletas        0
# numdocas         12838
# station_name     12838
# lat              12838
# lon              12838
# stationID        12838
# estado           12838
# diff_time        12838
# total_seconds    12838
# bike_taken           0
# dtype: int64

# %%
processed_stations[processed_stations.numdocas.isna()]
# Out:
#                            numbicicletas  numdocas station_name  lat  lon  \
# entity_ts
# 2022-07-01 12:00:00+00:00       6.500000       NaN         None  NaN  NaN
# 2022-07-01 16:00:00+00:00       7.666667       NaN         None  NaN  NaN
# 2022-07-03 03:00:00+00:00      17.000000       NaN         None  NaN  NaN
# 2022-07-03 13:00:00+00:00       9.750000       NaN         None  NaN  NaN
# 2022-07-03 21:00:00+00:00       8.750000       NaN         None  NaN  NaN
# ...                                  ...       ...          ...  ...  ...
# 2022-07-11 04:00:00+00:00       0.000000       NaN         None  NaN  NaN
# 2022-07-11 07:00:00+00:00       0.000000       NaN         None  NaN  NaN
# 2022-07-11 08:00:00+00:00       0.000000       NaN         None  NaN  NaN
# 2022-07-11 10:00:00+00:00       0.000000       NaN         None  NaN  NaN
# 2022-07-11 12:00:00+00:00       0.000000       NaN         None  NaN  NaN
#
#                            stationID estado diff_time  total_seconds  \
# entity_ts
# 2022-07-01 12:00:00+00:00        NaN   None       NaT            NaN
# 2022-07-01 16:00:00+00:00        NaN   None       NaT            NaN
# 2022-07-03 03:00:00+00:00        NaN   None       NaT            NaN
# 2022-07-03 13:00:00+00:00        NaN   None       NaT            NaN
# 2022-07-03 21:00:00+00:00        NaN   None       NaT            NaN
# ...                              ...    ...       ...            ...
# 2022-07-11 04:00:00+00:00        NaN   None       NaT            NaN
# 2022-07-11 07:00:00+00:00        NaN   None       NaT            NaN
# 2022-07-11 08:00:00+00:00        NaN   None       NaT            NaN
# 2022-07-11 10:00:00+00:00        NaN   None       NaT            NaN
# 2022-07-11 12:00:00+00:00        NaN   None       NaT            NaN
#
#                            bike_taken
# entity_ts
# 2022-07-01 12:00:00+00:00    0.500000
# 2022-07-01 16:00:00+00:00    4.333333
# 2022-07-03 03:00:00+00:00    0.000000
# 2022-07-03 13:00:00+00:00   -2.250000
# 2022-07-03 21:00:00+00:00    2.750000
# ...                               ...
# 2022-07-11 04:00:00+00:00    0.000000
# 2022-07-11 07:00:00+00:00    0.000000
# 2022-07-11 08:00:00+00:00    0.000000
# 2022-07-11 10:00:00+00:00    0.000000
# 2022-07-11 12:00:00+00:00    0.000000
#
# [12838 rows x 10 columns]

# %%
import plotly.express as px
import plotly.io as pio

# %%
fig = px.scatter_geo(data_frame=df_transformed,
                        lat='lat',
                        lon='lon',
                        color="numbicicletas",
                        hover_name="stationID", #size="numbicicletas",
                        animation_frame=df_transformed.index,
                        projection="natural earth",
                        #scope='europe'
                        )
#     fig.update_layout(lonaxis = dict(
#             showgrid = True,
#             gridwidth = 0.5,
#             range= [ -9.301437, -8.954681],
#             dtick = 5
#         ),
#         lataxis = dict(
#             showgrid = True,
#             gridwidth = 0.5,
#             range= [ 38.676979, 38.808727 ],
#             dtick = 5
#         )
#     )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 fig = px.scatter_geo(data_frame=df_transformed,
#       2                         lat='lat',
#       3                         lon='lon',
#       4                         color="numbicicletas",
#       5                         hover_name="stationID", #size="numbicicletas",
#       6                         animation_frame=df_transformed.index,
#       7                         projection="natural earth",
#       8                         #scope='europe'
#       9                         )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/plotly/express/_chart_types.py:1148, in scatter_geo(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, text, symbol, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1101 def scatter_geo(
#    1102     data_frame=None,
#    1103     lat=None,
#    (...)
#    1142     height=None,
#    1143 ) -> go.Figure:
#    1144     """
#    1145     In a geographic scatter plot, each row of `data_frame` is represented
#    1146     by a symbol mark on a map.
#    1147     """
# -> 1148     return make_figure(
#    1149         args=locals(),
#    1150         constructor=go.Scattergeo,
#    1151         trace_patch=dict(locationmode=locationmode),
#    1152     )
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/plotly/express/_core.py:2003, in make_figure(args, constructor, trace_patch, layout_patch)
#    1999 trace_specs, grouped_mappings, sizeref, show_colorbar = infer_config(
#    2000     args, constructor, trace_patch, layout_patch
#    2001 )
#    2002 grouper = [x.grouper or one_group for x in grouped_mappings] or [one_group]
# -> 2003 groups, orders = get_groups_and_orders(args, grouper)
#    2005 col_labels = []
#    2006 row_labels = []
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/plotly/express/_core.py:1965, in get_groups_and_orders(args, grouper)
#    1960 sorted_group_names = [
#    1961     g if len(required_grouper) != 1 else (g,) for g in group_indices
#    1962 ]
#    1964 for i, col in reversed(list(enumerate(required_grouper))):
# -> 1965     sorted_group_names = sorted(
#    1966         sorted_group_names,
#    1967         key=lambda g: orders[col].index(g[i]) if g[i] in orders[col] else -1,
#    1968     )
#    1970 # calculate the full group_names by inserting "" in the tuple index for one_group groups
#    1971 full_sorted_group_names = [list(t) for t in sorted_group_names]
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/plotly/express/_core.py:1967, in get_groups_and_orders.<locals>.<lambda>(g)
#    1960 sorted_group_names = [
#    1961     g if len(required_grouper) != 1 else (g,) for g in group_indices
#    1962 ]
#    1964 for i, col in reversed(list(enumerate(required_grouper))):
#    1965     sorted_group_names = sorted(
#    1966         sorted_group_names,
# -> 1967         key=lambda g: orders[col].index(g[i]) if g[i] in orders[col] else -1,
#    1968     )
#    1970 # calculate the full group_names by inserting "" in the tuple index for one_group groups
#    1971 full_sorted_group_names = [list(t) for t in sorted_group_names]
#
# KeyboardInterrupt:
